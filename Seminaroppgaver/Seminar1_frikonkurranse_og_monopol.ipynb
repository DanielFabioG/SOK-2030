# %% [markdown]
# # Seminar 1 - Frikonkurranse og monopol
#
# Etterspørsel etter vare Q er gitt ved p = 500 – 2Q, der p er prisen på gode Q, og Q er
# kvantum etterspurt. Anta at en monopolist produserer denne varen og har kostnadsfunksjon
# c(Q) = $Q^2$

# %%
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt

def pris(Q):
    return 500-2*Q

def kostnad(Q):
    return 2*Q

#def marginal_kostnad som er pris - kostnad
MR = pris(Q)-kostnad(Q)

# MR for grafen
def MR(Q):
    return 500-4*Q

Q = sp.symbols('Q', real = True)

eq = sp.Eq(MR(Q), kostnad(Q))

kvantum_løsning = sp.solve(eq, Q)[0]

# Løsning for kvantum
round(kvantum_løsning)

# Løsning for pris
pris_kvantum = pris(round(kvantum_løsning))

pris_kvantum
# Out:
# 334

# %% [markdown]
# Anta at monopolisten vil maksimere sin profitt. Hvor mye produserer
# monopolbedriften og til hvilken pris? Forklar intuisjonen bak tilpasningen.

# %%
#drawing 800 points in the interval 0.0 to 300
Q = np.linspace(1,300,300)

#drawing marginalrevenue
plt.plot(Q,MR(Q),label='MR')

#drawing marginalcost
plt.plot(Q,kostnad(Q),label='MC')
#drawing demand
plt.plot(Q,pris(Q),color='green',label='Etterspørsel')

#adding legend:
plt.legend(loc='lower right')

#setting the axis lables
plt.ylabel('Pris')
plt.xlabel('Enheter')

#setting the range of y values (the price) to be between 0 and 500, so that we can more
#easily see the equilibrium price
plt.ylim((-2,500))
# Out:
# (-2.0, 500.0)

# %% [markdown]
# Hva ville markedstilpasningen ha vært under frikonkurranse konkurranse? Forklar ditt
# svar og kommenter den samfunnsøkonomiske lønnsomheten ved denne
# markedstilpasningen. Hvor mye taper samfunnet ved monopoltilpasning?

# %%
Q = sp.symbols('Q', real = True)

eq_2 = sp.Eq(pris(Q), kostnad(Q))

løsning_kvantum = sp.solve(eq_2, Q)[0]
løsning_kvantum

# Løsning for pris
pris_kvantum = pris(round(løsning_kvantum))

# %%
#drawing 800 points in the interval 0.0 to 300
Q = np.linspace(1,300,300)

#drawing marginalrevenue
plt.plot(Q,pris(Q),label='MR')
#drawing demand
plt.plot(Q,kostnad(Q),color='green',label='Etterspørsel')

#adding legend:
plt.legend(loc='lower right')

#setting the axis lables
plt.ylabel('Pris')
plt.xlabel('Enheter')

#setting the range of y values (the price) to be between 0 and 500, so that we can more
#easily see the equilibrium price
plt.ylim((-2,500))
# Out:
# (-2.0, 500.0)
